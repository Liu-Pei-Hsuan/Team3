# %%
import pandas as pd
import pandas as pd
from sqlalchemy import create_engine
import sqlalchemy

# %%
# engine = create_engine('mysql+pymysql://{}:{}@172.20.10.10/mydb?charset=utf8mb4_general_ci'.format('student','student'), encoding='utf-8')
engine = create_engine('mysql+pymysql://{}:{}@172.20.10.10/mydb?'.format('student','student'))

#條件設定
apikey='84d3f5d7-6629-4967-9218-f0a6dae7be37'
format_get='csv'
year_month='2021_11'
# url='https://data.epa.gov.tw/api/v1/aqx_p_488?api_key={}&year_month={}&format={}'.format(apikey,year_month,format_get)
url='AQI_DATA/2018_01_空氣品質指標(AQI)_out.csv'
df = pd.read_csv (url, index_col = 0)
#排序表格
#篩選出桃園市
# filter=df.loc[df['County']=="桃園市"][['DataCreationDate','County','AQI','SO2','CO','O3','PM10','PM2.5','NO2','NOx','NO','WindSpeed','WindDirec','Longitude','Latitude']]
filter=df[['DataCreationDate','County','AQI','SO2','CO','O3','PM10','PM2.5','NO2','NOx','NO','WindSpeed','WindDirec']]
filter.to_sql(name='AQI_hour', con=engine, if_exists = 'append', index=False)
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# ~\.conda\envs\py38\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1781                 if not evt_handled:
# -> 1782                     self.dialect.do_executemany(
#    1783                         cursor, statement, parameters, context
#
# ~\.conda\envs\py38\lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py in do_executemany(self, cursor, statement, parameters, context)
#     192     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 193         rowcount = cursor.executemany(statement, parameters)
#     194         if context is not None:
#
# ~\.conda\envs\py38\lib\site-packages\pymysql\cursors.py in executemany(self, query, args)
#     172             assert q_values[0] == "(" and q_values[-1] == ")"
# --> 173             return self._do_execute_many(
#     174                 q_prefix,
#
# ~\.conda\envs\py38\lib\site-packages\pymysql\cursors.py in _do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     210             sql += v
# --> 211         rows += self.execute(sql + postfix)
#     212         self.rowcount = rows
#
# ~\.conda\envs\py38\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     147
# --> 148         result = self._query(query)
#     149         self._executed = query
#
# ~\.conda\envs\py38\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     309         self._clear_result()
# --> 310         conn.query(q)
#     311         self._do_get_result()
#
# ~\.conda\envs\py38\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     547         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 548         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     549         return self._affected_rows
#
# ~\.conda\envs\py38\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#     774             result = MySQLResult(self)
# --> 775             result.read()
#     776         self._result = result
#
# ~\.conda\envs\py38\lib\site-packages\pymysql\connections.py in read(self)
#    1155         try:
# -> 1156             first_packet = self.connection._read_packet()
#    1157
#
# ~\.conda\envs\py38\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     724                 self._result.unbuffered_active = False
# --> 725             packet.raise_for_error()
#     726         return packet
#
# ~\.conda\envs\py38\lib\site-packages\pymysql\protocol.py in raise_for_error(self)
#     220             print("errno =", errno)
# --> 221         err.raise_mysql_exception(self._data)
#     222
#
# ~\.conda\envs\py38\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     142         errorclass = InternalError if errno < 1000 else OperationalError
# --> 143     raise errorclass(errno, errval)
#
# DataError: (1366, "Incorrect string value: '\\xE6\\xA1\\x83\\xE5\\x9C\\x92...' for column `mydb`.`sample_table5`.`County` at row 1")
#
# The above exception was the direct cause of the following exception:
#
# DataError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8708/509816542.py in <module>
#      18 # filter=df.loc[df['County']=="桃園市"][['DataCreationDate','County','AQI','SO2','CO','O3','PM10','PM2.5','NO2','NOx','NO','WindSpeed','WindDirec','Longitude','Latitude']]
#      19 filter=df[['DataCreationDate','County','AQI','SO2','CO','O3','PM10','PM2.5','NO2','NOx','NO','WindSpeed','WindDirec']]
# ---> 20 filter.to_sql(name='sample_table5', con=engine, if_exists = 'append', index=False)
#
# ~\.conda\envs\py38\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2870         from pandas.io import sql
#    2871
# -> 2872         sql.to_sql(
#    2873             self,
#    2874             name,
#
# ~\.conda\envs\py38\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     715         )
#     716
# --> 717     pandas_sql.to_sql(
#     718         frame,
#     719         name,
#
# ~\.conda\envs\py38\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1759         )
#    1760
# -> 1761         sql_engine.insert_records(
#    1762             table=table,
#    1763             con=self.connectable,
#
# ~\.conda\envs\py38\lib\site-packages\pandas\io\sql.py in insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1348                 raise ValueError("inf cannot be used with MySQL") from err
#    1349             else:
# -> 1350                 raise err
#    1351
#    1352
#
# ~\.conda\envs\py38\lib\site-packages\pandas\io\sql.py in insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1338
#    1339         try:
# -> 1340             table.insert(chunksize=chunksize, method=method)
#    1341         except exc.SQLAlchemyError as err:
#    1342             # GH34431
#
# ~\.conda\envs\py38\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     965
#     966                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 967                 exec_insert(conn, keys, chunk_iter)
#     968
#     969     def _query_iterator(
#
# ~\.conda\envs\py38\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     880         """
#     881         data = [dict(zip(keys, row)) for row in data_iter]
# --> 882         conn.execute(self.table.insert(), data)
#     883
#     884     def _execute_insert_multi(self, conn, keys: list[str], data_iter):
#
# ~\.conda\envs\py38\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    1287             )
#    1288         else:
# -> 1289             return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#    1290
#    1291     def _execute_function(self, func, multiparams, params, execution_options):
#
# ~\.conda\envs\py38\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     323     ):
#     324         if _force or self.supports_execution:
# --> 325             return connection._execute_clauseelement(
#     326                 self, multiparams, params, execution_options
#     327             )
#
# ~\.conda\envs\py38\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1479             linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1480         )
# -> 1481         ret = self._execute_context(
#    1482             dialect,
#    1483             dialect.execution_ctx_cls._init_compiled,
#
# ~\.conda\envs\py38\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1843
#    1844         except BaseException as e:
# -> 1845             self._handle_dbapi_exception(
#    1846                 e, statement, parameters, cursor, context
#    1847             )
#
# ~\.conda\envs\py38\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2024                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2025             elif should_wrap:
# -> 2026                 util.raise_(
#    2027                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2028                 )
#
# ~\.conda\envs\py38\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~\.conda\envs\py38\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1780                             break
#    1781                 if not evt_handled:
# -> 1782                     self.dialect.do_executemany(
#    1783                         cursor, statement, parameters, context
#    1784                     )
#
# ~\.conda\envs\py38\lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py in do_executemany(self, cursor, statement, parameters, context)
#     191
#     192     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 193         rowcount = cursor.executemany(statement, parameters)
#     194         if context is not None:
#     195             context._rowcount = rowcount
#
# ~\.conda\envs\py38\lib\site-packages\pymysql\cursors.py in executemany(self, query, args)
#     171             q_postfix = m.group(3) or ""
#     172             assert q_values[0] == "(" and q_values[-1] == ")"
# --> 173             return self._do_execute_many(
#     174                 q_prefix,
#     175                 q_values,
#
# ~\.conda\envs\py38\lib\site-packages\pymysql\cursors.py in _do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     209                 sql += b","
#     210             sql += v
# --> 211         rows += self.execute(sql + postfix)
#     212         self.rowcount = rows
#     213         return rows
#
# ~\.conda\envs\py38\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     146         query = self.mogrify(query, args)
#     147
# --> 148         result = self._query(query)
#     149         self._executed = query
#     150         return result
#
# ~\.conda\envs\py38\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     308         self._last_executed = q
#     309         self._clear_result()
# --> 310         conn.query(q)
#     311         self._do_get_result()
#     312         return self.rowcount
#
# ~\.conda\envs\py38\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     546             sql = sql.encode(self.encoding, "surrogateescape")
#     547         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 548         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     549         return self._affected_rows
#     550
#
# ~\.conda\envs\py38\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#     773         else:
#     774             result = MySQLResult(self)
# --> 775             result.read()
#     776         self._result = result
#     777         if result.server_status is not None:
#
# ~\.conda\envs\py38\lib\site-packages\pymysql\connections.py in read(self)
#    1154     def read(self):
#    1155         try:
# -> 1156             first_packet = self.connection._read_packet()
#    1157
#    1158             if first_packet.is_ok_packet():
#
# ~\.conda\envs\py38\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     723             if self._result is not None and self._result.unbuffered_active is True:
#     724                 self._result.unbuffered_active = False
# --> 725             packet.raise_for_error()
#     726         return packet
#     727
#
# ~\.conda\envs\py38\lib\site-packages\pymysql\protocol.py in raise_for_error(self)
#     219         if DEBUG:
#     220             print("errno =", errno)
# --> 221         err.raise_mysql_exception(self._data)
#     222
#     223     def dump(self):
#
# ~\.conda\envs\py38\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     141     if errorclass is None:
#     142         errorclass = InternalError if errno < 1000 else OperationalError
# --> 143     raise errorclass(errno, errval)
#
# DataError: (pymysql.err.DataError) (1366, "Incorrect string value: '\\xE6\\xA1\\x83\\xE5\\x9C\\x92...' for column `mydb`.`sample_table5`.`County` at row 1")
# [SQL: INSERT INTO sample_table5 (`DataCreationDate`, `County`, `AQI`, `SO2`, `CO`, `O3`, `PM10`, `PM2.5`, `NO2`, `NOx`, `NO`, `WindSpeed`, `WindDirec`) VALUES (%(DataCreationDate)s, %(County)s, %(AQI)s, %(SO2)s, %(CO)s, %(O3)s, %(PM10)s, %(PM2.5)s, %(NO2)s, %(NOx)s, %(NO)s, %(WindSpeed)s, %(WindDirec)s)]
# [parameters: ({'DataCreationDate': '2018-01-31 23:00', 'County': '桃園市', 'AQI': 38.0, 'SO2': 1.8, 'CO': 0.4, 'O3': 36.0, 'PM10': 29.0, 'PM2.5': '18', 'NO2': 0.5, 'NOx': 8.6, 'NO': 8.1, 'WindSpeed': 3.7, 'WindDirec': 34.0}, {'DataCreationDate': '2018-01-31 23:00', 'County': '桃園市', 'AQI': 25.0, 'SO2': 2.2, 'CO': 0.6, 'O3': 31.0, 'PM10': 21.0, 'PM2.5': '2', 'NO2': 16.0, 'NOx': 21.0, 'NO': 5.2, 'WindSpeed': 2.4, 'WindDirec': 31.0}, {'DataCreationDate': '2018-01-31 23:00', 'County': '桃園市', 'AQI': 31.0, 'SO2': 2.4, 'CO': 0.33, 'O3': 41.0, 'PM10': 19.0, 'PM2.5': '7', 'NO2': 5.2, 'NOx': 6.3, 'NO': 1.1, 'WindSpeed': 2.2, 'WindDirec': 17.0}, {'DataCreationDate': '2018-01-31 23:00', 'County': '桃園市', 'AQI': 30.0, 'SO2': 2.0, 'CO': 0.38, 'O3': 39.0, 'PM10': 17.0, 'PM2.5': '4', 'NO2': 7.9, 'NOx': 9.1, 'NO': 1.2, 'WindSpeed': 4.7, 'WindDirec': 57.0}, {'DataCreationDate': '2018-01-31 23:00', 'County': '桃園市', 'AQI': 39.0, 'SO2': 0.8, 'CO': 0.41, 'O3': 46.0, 'PM10': 23.0, 'PM2.5': 'ND', 'NO2': 1.1, 'NOx': 6.0, 'NO': 4.8, 'WindSpeed': 12.0, 'WindDirec': 22.0}, {'DataCreationDate': '2018-01-31 23:00', 'County': '桃園市', 'AQI': 35.0, 'SO2': 0.8, 'CO': 0.44, 'O3': 39.0, 'PM10': 25.0, 'PM2.5': '8', 'NO2': None, 'NOx': None, 'NO': None, 'WindSpeed': 8.4, 'WindDirec': 11.0}, {'DataCreationDate': '2018-01-31 22:00', 'County': '桃園市', 'AQI': 28.0, 'SO2': 2.1, 'CO': 0.67, 'O3': 24.0, 'PM10': 23.0, 'PM2.5': '4', 'NO2': 22.0, 'NOx': 33.0, 'NO': 10.0, 'WindSpeed': 2.3, 'WindDirec': 21.0}, {'DataCreationDate': '2018-01-31 22:00', 'County': '桃園市', 'AQI': 33.0, 'SO2': 1.8, 'CO': 0.45, 'O3': 33.0, 'PM10': 33.0, 'PM2.5': '18', 'NO2': 0.4, 'NOx': 10.0, 'NO': 10.0, 'WindSpeed': 4.3, 'WindDirec': 34.0}  ... displaying 10 of 4427 total bound parameter sets ...  {'DataCreationDate': '2018-01-01 00:00', 'County': '桃園市', 'AQI': 113.0, 'SO2': 1.4, 'CO': 0.55, 'O3': 32.0, 'PM10': 83.0, 'PM2.5': '16.0', 'NO2': 14.0, 'NOx': 19.0, 'NO': 5.3, 'WindSpeed': 1.5, 'WindDirec': 0.2}, {'DataCreationDate': '2018-01-01 00:00', 'County': '桃園市', 'AQI': 91.0, 'SO2': 1.6, 'CO': 0.32, 'O3': 41.0, 'PM10': 89.0, 'PM2.5': '14.0', 'NO2': 12.0, 'NOx': 13.0, 'NO': 1.1, 'WindSpeed': 5.1, 'WindDirec': 55.0})]
# (Background on this error at: https://sqlalche.me/e/14/9h9h)

# %%
url='AQI_DATA/2018_01_空氣品質指標(AQI)_out.csv'
df = pd.read_csv (url, index_col = 0)

conn = pymysql.Connect(
    host = '172.20.10.10',
    port = 3306,
    user = 'root',
    passwd = 'P@ssw0rd',
    db = 'test'
)

cur = conn.cursor()
sql = 'insert into prdinfo (prdClass,prdName,prdPrice,prdImg,prdUrl) values (%s,%s,%s,%s,%s)'
cur.execute('delete from prdinfo')
cur.executemany(sql,prdData)
conn.commit()
print('資料筆數 :',cur.execute("select * from prdinfo"))
cur.close()
conn.close()

# %%
# !pip install sqlalchemy
# Out:
# Collecting sqlalchemy
#   Downloading SQLAlchemy-1.4.27-cp38-cp38-win_amd64.whl (1.5 MB)
# Collecting greenlet!=0.4.17
#   Downloading greenlet-1.1.2-cp38-cp38-win_amd64.whl (101 kB)
# Installing collected packages: greenlet, sqlalchemy
# Successfully installed greenlet-1.1.2 sqlalchemy-1.4.27

# %%
import os
import requests
import pandas as pd
from time import sleep
from bs4 import BeautifulSoup
import json
url = 'https://data.epa.gov.tw/api/3/action/datastore_search?api_key=9be7b239-557b-4c10-9775-78cadfc555e9&resource_id=70d312ec-c971-42c5-92da-7a6017e3a915&q={%22County%22:%22%E6%A1%83%E5%9C%92%E5%B8%82%22}'
resp = requests.get(url)
soup = BeautifulSoup(resp.text, features="html.parser")
data = json.loads(resp.text)
    # 或者這樣
    # data = json.loads(jsonfile.read())
# print(data)
# soup = BeautifulSoup(resp.text, features="html.parser")

# %%
import os
import requests
import pandas as pd
from time import sleep
from bs4 import BeautifulSoup
import json
url = 'https://data.epa.gov.tw/api/3/action/datastore_search?api_key=9be7b239-557b-4c10-9775-78cadfc555e9&resource_id=70d312ec-c971-42c5-92da-7a6017e3a915&q={%22County%22:%22%E6%A1%83%E5%9C%92%E5%B8%82%22}&limit=4320'
resp = requests.get(url)
soup = BeautifulSoup(resp.text, features="html.parser")
data = json.loads(resp.text)
#轉 pandas 用 list
json_to_pandas=[]
for json_in in (data['result']['records']):
    #轉換格式為pandas接受格式
    json_to_pandas.append(json_in)
# with open("test.json","w",encoding="utf-8") as f:
#     f.write(json.dumps(json_to_pandas))
#json轉df
df = pd.read_json(json.dumps(json_to_pandas),encoding="utf-8", orient='records')
#排版df
df_done=df[['DataCreationDate','County','AQI','SO2','CO','O3','PM10','PM2.5','NO2','NOx','NO','WindSpeed','WindDirec']]
#存到CSV
df_done.to_csv("test_out.csv")

# %%
#轉 pandas 用 list
json_to_pandas=[]
for json_in in (data['result']['records']):
    #轉換格式為pandas接受格式
    json_to_pandas.append(json_in)
# with open("test.json","w",encoding="utf-8") as f:
#     f.write(json.dumps(json_to_pandas))
#json轉df
df = pd.read_json(json.dumps(json_to_pandas),encoding="utf-8", orient='records')
#排版df
df_done=df[['DataCreationDate','County','AQI','SO2','CO','O3','PM10','PM2.5','NO2','NOx','NO','WindSpeed','WindDirec']]
# 2021-11-30 13:00 桃園市 大園
# 2021-11-30 13:00 桃園市 桃園
# 2021-11-30 13:00 桃園市 龍潭
# 2021-11-30 13:00 桃園市 中壢
# 2021-11-30 13:00 桃園市 觀音
# 2021-11-30 12:00 桃園市 平鎮
# 2021-11-30 12:00 桃園市 桃園
# 2021-11-30 12:00 桃園市 觀音
# 2021-11-30 12:00 桃園市 大園
# 2021-11-30 12:00 桃園市 龍潭
# 2021-11-30 12:00 桃園市 中壢
# 2021-11-30 11:00 桃園市 大園
# 2021-11-30 11:00 桃園市 龍潭
# 2021-11-30 11:00 桃園市 平鎮
# 2021-11-30 11:00 桃園市 中壢
# 2021-11-30 11:00 桃園市 桃園
# 2021-11-30 11:00 桃園市 觀音
# 2021-11-30 10:00 桃園市 龍潭
# 2021-11-30 10:00 桃園市 中壢
# 2021-11-30 10:00 桃園市 桃園
# 2021-11-30 10:00 桃園市 大園
# 2021-11-30 10:00 桃園市 平鎮
# 2021-11-30 10:00 桃園市 觀音
# 2021-11-30 09:00 桃園市 平鎮
# 2021-11-30 09:00 桃園市 中壢
# 2021-11-30 09:00 桃園市 大園
# 2021-11-30 09:00 桃園市 龍潭
# 2021-11-30 09:00 桃園市 觀音
# 2021-11-30 09:00 桃園市 桃園
# 2021-11-30 08:00 桃園市 大園
# 2021-11-30 08:00 桃園市 桃園
# 2021-11-30 08:00 桃園市 龍潭
# 2021-11-30 08:00 桃園市 平鎮
# 2021-11-30 08:00 桃園市 觀音
# 2021-11-30 08:00 桃園市 中壢
# 2021-11-30 07:00 桃園市 平鎮
# 2021-11-30 07:00 桃園市 中壢
# 2021-11-30 07:00 桃園市 桃園
# 2021-11-30 07:00 桃園市 大園

# %%
data['result']['records']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21808/3238553144.py in <module>
# ----> 1 data['result']['records']
#
# NameError: name 'data' is not defined

# %%
#取得2018~2021的
count_time=0
for i in soup.find_all("tr"):
    if count_time < 2 or count_time > 49:
        count_time+=1
        pass 
    else:
        if count_time == 2 :
            day=str('2021/12')
            resource=i.find("a", href=True)['href'].split('/')[4]            
            print(day + '|' + resource)
            count_time+=1    
        else:
            day=i.text.replace('\n','').replace(' ','').replace('空氣品質指標(AQI)(歷史資料)(','').replace(')下載','')
            resource=i.find("a", href=True)['href'].split('/')[4]
            print(day + '|' + resource)
            count_time+=1

# %%
# to_csv
import os
import requests
import pandas as pd
from time import sleep
from bs4 import BeautifulSoup
import json
resource_id=0
# resource_id to get totol_______start
def get_totol(resource_id):
    limit=10
    url_get_totol = 'https://data.epa.gov.tw/api/3/action/datastore_search?api_key=9be7b239-557b-4c10-9775-78cadfc555e9&resource_id=' + resource_id + '&q={%22County%22:%22%E6%A1%83%E5%9C%92%E5%B8%82%22}&limit=' + str(limit)
    resp = requests.get(url_get_totol)
    soup = BeautifulSoup(resp.text, features="html.parser")
    data = json.loads(resp.text)
    totol=data['result']['total']
    return str(totol)
# resource_id to get totol_______end

def get_data_save_to_csv(date,resource_id,totle):
    print(date+"..Start!")
    url_get_data = 'https://data.epa.gov.tw/api/3/action/datastore_search?api_key=9be7b239-557b-4c10-9775-78cadfc555e9&resource_id=' + resource_id + '&q={%22County%22:%22%E6%A1%83%E5%9C%92%E5%B8%82%22}&limit=' + str(totle)
    res = requests.get(url_get_data)
#     soup = BeautifulSoup(res.text, features="html.parser")
    data = json.loads(res.text)
    #轉 pandas 用 list
    json_to_pandas=[]
    for json_in in (data['result']['records']):
        #轉換格式為pandas接受格式
        json_to_pandas.append(json_in)
    # with open("test.json","w",encoding="utf-8") as f:
    #     f.write(json.dumps(json_to_pandas))
    #json轉df
    df = pd.read_json(json.dumps(json_to_pandas),encoding="utf-8-sig", orient='records')
    #排版df
    df_done=df[['DataCreationDate','County','SiteName','AQI','SO2','CO','O3','PM10','PM2.5','NO2','NOx','NO','WindSpeed','WindDirec']]
    #存到CSV
    date_change=date[0:4]+"_"+date[5:7]
    df_done.to_csv("AQI_DATA/" + date_change + "_空氣品質指標(AQI)_out.csv",encoding="utf-8-sig")
    print(date+"..Done!")

#取得所有aqx_p_488 日期與 resource_id _____start
url = 'https://data.epa.gov.tw/dataset/aqx_p_488'
resp = requests.get(url)
soup = BeautifulSoup(resp.text, features="html.parser")
list_date=[]
dict_resource_id={}
count_time=0
for i in soup.find_all("tr"):
    if count_time < 2 :
        count_time+=1
        pass 
    else:
        if count_time == 2 :
            day=str('2021/12')
            resource=i.find("a", href=True)['href'].split('/')[4]   
            list_date.append(day)
            dict_resource_id[day]=resource
#             print(day + '|' + resource)
            count_time+=1    
        else:
            try:
                day=i.text.replace('\n','').replace(' ','').replace('空氣品質指標(AQI)(歷史資料)(','').replace(')下載','')
                resource=i.find("a", href=True)['href'].split('/')[4]
                list_date.append(day)
                dict_resource_id[day]=resource
#                 print(day + '|' + resource)
                count_time+=1
            except:
                count_time+=1
#取得所有aqx_p_488 日期與 resource_id _____end

#設定要get到的範圍_____start
input_list=[]
start_year=2021
start_month=12
end_year=2018
end_month=1
for yearlist in range(end_year,start_year+1,1):
#     print (yearlist)
    if end_year != yearlist:
        for month in range(1,13):
            input_list.append(str(yearlist) + "/" + str(month).zfill(2))
    else:
        for month in range(end_month,13):
            input_list.append(str(yearlist) + "/" + str(month).zfill(2))
input_list[0]
#設定要get到的範圍_____end

#data_in get date
for data_in in input_list:
    #get resource_id 
    resource_id=dict_resource_id.get(data_in)
#     print(resource_id)
    totle=get_totol(resource_id)
#     print(get_totol(resource_id))
    get_data_save_to_csv(data_in,resource_id,totle)
# Out:
# 2018/01..Start!
# 2018/01..Done!
# 2018/02..Start!
# 2018/02..Done!
# 2018/03..Start!
# 2018/03..Done!
# 2018/04..Start!
# 2018/04..Done!
# 2018/05..Start!
# 2018/05..Done!
# 2018/06..Start!
# 2018/06..Done!
# 2018/07..Start!
# 2018/07..Done!
# 2018/08..Start!
# 2018/08..Done!
# 2018/09..Start!
# 2018/09..Done!
# 2018/10..Start!
# 2018/10..Done!
# 2018/11..Start!
# 2018/11..Done!
# 2018/12..Start!
# 2018/12..Done!
# 2019/01..Start!
# 2019/01..Done!
# 2019/02..Start!
# 2019/02..Done!
# 2019/03..Start!
# 2019/03..Done!
# 2019/04..Start!
# 2019/04..Done!
# 2019/05..Start!
# 2019/05..Done!
# 2019/06..Start!
# 2019/06..Done!
# 2019/07..Start!
# 2019/07..Done!
# 2019/08..Start!
# 2019/08..Done!
# 2019/09..Start!
# 2019/09..Done!
# 2019/10..Start!
# 2019/10..Done!
# 2019/11..Start!
# 2019/11..Done!
# 2019/12..Start!
# 2019/12..Done!
# 2020/01..Start!
# 2020/01..Done!
# 2020/02..Start!
# 2020/02..Done!
# 2020/03..Start!
# 2020/03..Done!
# 2020/04..Start!
# 2020/04..Done!
# 2020/05..Start!
# 2020/05..Done!
# 2020/06..Start!
# 2020/06..Done!
# 2020/07..Start!
# 2020/07..Done!
# 2020/08..Start!
# 2020/08..Done!
# 2020/09..Start!
# 2020/09..Done!
# 2020/10..Start!
# 2020/10..Done!
# 2020/11..Start!
# 2020/11..Done!
# 2020/12..Start!
# 2020/12..Done!
# 2021/01..Start!
# 2021/01..Done!
# 2021/02..Start!
# 2021/02..Done!
# 2021/03..Start!
# 2021/03..Done!
# 2021/04..Start!
# 2021/04..Done!
# 2021/05..Start!
# 2021/05..Done!
# 2021/06..Start!
# 2021/06..Done!
# 2021/07..Start!
# 2021/07..Done!
# 2021/08..Start!
# 2021/08..Done!
# 2021/09..Start!
# 2021/09..Done!
# 2021/10..Start!
# 2021/10..Done!
# 2021/11..Start!
# 2021/11..Done!
# 2021/12..Start!
# 2021/12..Done!

# %%
#創建Table
engine = create_engine('mysql+pymysql://{}:{}@172.20.10.10/mydb'.format('student','student'))
engine.execute('CREATE TABLE IF NOT EXISTS `AQI_hour` ('
                '`DataCreationDate` text DEFAULT NULL,'
                '`SiteName` text DEFAULT NULL,'
                '`County` text DEFAULT NULL,'
                '`AQI` double DEFAULT NULL,'
                '`SO2` double DEFAULT NULL,'
                '`CO` double DEFAULT NULL,'
                '`O3` double DEFAULT NULL,'
                '`PM10` double DEFAULT NULL,'
                '`PM2.5` text DEFAULT NULL,'
                '`NO2` double DEFAULT NULL,'
                '`NOx` double DEFAULT NULL,'
                '`NO` double DEFAULT NULL,'
                '`WindSpeed` double DEFAULT NULL,'
                '`WindDirec` double DEFAULT NULL)'
                'ENGINE=InnoDB DEFAULT CHARSET=utf8mb4;')

# %%
# to_mysql
import os
import requests
import pandas as pd
from time import sleep
from bs4 import BeautifulSoup
import json
from sqlalchemy import create_engine
import sqlalchemy

resource_id=0
# resource_id to get totol_______start
def get_totol(resource_id):
    limit=10
    url_get_totol = 'https://data.epa.gov.tw/api/3/action/datastore_search?api_key=9be7b239-557b-4c10-9775-78cadfc555e9&resource_id=' + resource_id + '&q={%22County%22:%22%E6%A1%83%E5%9C%92%E5%B8%82%22}&limit=' + str(limit)
    resp = requests.get(url_get_totol)
    soup = BeautifulSoup(resp.text, features="html.parser")
    data = json.loads(resp.text)
    totol=data['result']['total']
    return str(totol)
# resource_id to get totol_______end

def get_data_save_to_sql(date,resource_id,totle):
    engine = create_engine('mysql+pymysql://{}:{}@mqtt2.tibame.cloud/AQI_History'.format('hsuan','hsuan'))
    print(date+"..Start!")
    url_get_data = 'https://data.epa.gov.tw/api/3/action/datastore_search?api_key=9be7b239-557b-4c10-9775-78cadfc555e9&resource_id=' + resource_id + '&q={%22County%22:%22%E6%A1%83%E5%9C%92%E5%B8%82%22}&limit=' + str(totle)
    res = requests.get(url_get_data)
#     soup = BeautifulSoup(res.text, features="html.parser")
    data = json.loads(res.text)
    #轉 pandas 用 list
    json_to_pandas=[]
    for json_in in (data['result']['records']):
        #轉換格式為pandas接受格式
        json_to_pandas.append(json_in)
    # with open("test.json","w",encoding="utf-8") as f:
    #     f.write(json.dumps(json_to_pandas))
    #json轉df
    df = pd.read_json(json.dumps(json_to_pandas),encoding="utf-8-sig", orient='records')
    #排版df
    df_done=df[['DataCreationDate','County','SiteName','AQI','SO2','CO','O3','PM10','PM2.5','NO2','NOx','NO','WindSpeed','WindDirec']]
    #存到CSV
    date_change=date[0:4]+"_"+date[5:7]
    df_done.to_sql(name='AQI_hour', con=engine, if_exists = 'append', index=False)
    print(date+"..Done!")

#取得所有aqx_p_488 日期與 resource_id _____start
url = 'https://data.epa.gov.tw/dataset/aqx_p_488'
resp = requests.get(url)
soup = BeautifulSoup(resp.text, features="html.parser")
list_date=[]
dict_resource_id={}
count_time=0
for i in soup.find_all("tr"):
    if count_time < 2 :
        count_time+=1
        pass 
    else:
        if count_time == 2 :
            day=str('2021/12')
            resource=i.find("a", href=True)['href'].split('/')[4]   
            list_date.append(day)
            dict_resource_id[day]=resource
#             print(day + '|' + resource)
            count_time+=1    
        else:
            try:
                day=i.text.replace('\n','').replace(' ','').replace('空氣品質指標(AQI)(歷史資料)(','').replace(')下載','')
                resource=i.find("a", href=True)['href'].split('/')[4]
                list_date.append(day)
                dict_resource_id[day]=resource
#                 print(day + '|' + resource)
                count_time+=1
            except:
                count_time+=1
#取得所有aqx_p_488 日期與 resource_id _____end

#設定要get到的範圍_____start
input_list=[]
start_year=2021
start_month=12
end_year=2018
end_month=1
for yearlist in range(end_year,start_year+1,1):
#     print (yearlist)
    if end_year != yearlist:
        for month in range(1,13):
            input_list.append(str(yearlist) + "/" + str(month).zfill(2))
    else:
        for month in range(end_month,13):
            input_list.append(str(yearlist) + "/" + str(month).zfill(2))
input_list[0]
#設定要get到的範圍_____end

#data_in get date
for data_in in input_list:
    #get resource_id 
    resource_id=dict_resource_id.get(data_in)
#     print(resource_id)
    totle=get_totol(resource_id)
#     print(get_totol(resource_id))
    get_data_save_to_sql(data_in,resource_id,totle)
# Out:
# 2018/01..Start!
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\.conda\envs\py38\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1781                 if not evt_handled:
# -> 1782                     self.dialect.do_executemany(
#    1783                         cursor, statement, parameters, context
#
# ~\.conda\envs\py38\lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py in do_executemany(self, cursor, statement, parameters, context)
#     192     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 193         rowcount = cursor.executemany(statement, parameters)
#     194         if context is not None:
#
# ~\.conda\envs\py38\lib\site-packages\pymysql\cursors.py in executemany(self, query, args)
#     172             assert q_values[0] == "(" and q_values[-1] == ")"
# --> 173             return self._do_execute_many(
#     174                 q_prefix,
#
# ~\.conda\envs\py38\lib\site-packages\pymysql\cursors.py in _do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     210             sql += v
# --> 211         rows += self.execute(sql + postfix)
#     212         self.rowcount = rows
#
# ~\.conda\envs\py38\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     147
# --> 148         result = self._query(query)
#     149         self._executed = query
#
# ~\.conda\envs\py38\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     309         self._clear_result()
# --> 310         conn.query(q)
#     311         self._do_get_result()
#
# ~\.conda\envs\py38\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     547         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 548         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     549         return self._affected_rows
#
# ~\.conda\envs\py38\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#     774             result = MySQLResult(self)
# --> 775             result.read()
#     776         self._result = result
#
# ~\.conda\envs\py38\lib\site-packages\pymysql\connections.py in read(self)
#    1155         try:
# -> 1156             first_packet = self.connection._read_packet()
#    1157
#
# ~\.conda\envs\py38\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     724                 self._result.unbuffered_active = False
# --> 725             packet.raise_for_error()
#     726         return packet
#
# ~\.conda\envs\py38\lib\site-packages\pymysql\protocol.py in raise_for_error(self)
#     220             print("errno =", errno)
# --> 221         err.raise_mysql_exception(self._data)
#     222
#
# ~\.conda\envs\py38\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     142         errorclass = InternalError if errno < 1000 else OperationalError
# --> 143     raise errorclass(errno, errval)
#
# OperationalError: (1054, "Unknown column 'PM2.5' in 'field list'")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21808/154697806.py in <module>
#      99     totle=get_totol(resource_id)
#     100 #     print(get_totol(resource_id))
# --> 101     get_data_save_to_sql(data_in,resource_id,totle)
#
# ~\AppData\Local\Temp/ipykernel_21808/154697806.py in get_data_save_to_sql(date, resource_id, totle)
#      41     #存到CSV
#      42     date_change=date[0:4]+"_"+date[5:7]
# ---> 43     df_done.to_sql(name='AQI_hour', con=engine, if_exists = 'append', index=False)
#      44     print(date+"..Done!")
#      45
#
# ~\.conda\envs\py38\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2870         from pandas.io import sql
#    2871
# -> 2872         sql.to_sql(
#    2873             self,
#    2874             name,
#
# ~\.conda\envs\py38\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     715         )
#     716
# --> 717     pandas_sql.to_sql(
#     718         frame,
#     719         name,
#
# ~\.conda\envs\py38\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1759         )
#    1760
# -> 1761         sql_engine.insert_records(
#    1762             table=table,
#    1763             con=self.connectable,
#
# ~\.conda\envs\py38\lib\site-packages\pandas\io\sql.py in insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1348                 raise ValueError("inf cannot be used with MySQL") from err
#    1349             else:
# -> 1350                 raise err
#    1351
#    1352
#
# ~\.conda\envs\py38\lib\site-packages\pandas\io\sql.py in insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1338
#    1339         try:
# -> 1340             table.insert(chunksize=chunksize, method=method)
#    1341         except exc.SQLAlchemyError as err:
#    1342             # GH34431
#
# ~\.conda\envs\py38\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     965
#     966                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 967                 exec_insert(conn, keys, chunk_iter)
#     968
#     969     def _query_iterator(
#
# ~\.conda\envs\py38\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     880         """
#     881         data = [dict(zip(keys, row)) for row in data_iter]
# --> 882         conn.execute(self.table.insert(), data)
#     883
#     884     def _execute_insert_multi(self, conn, keys: list[str], data_iter):
#
# ~\.conda\envs\py38\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    1287             )
#    1288         else:
# -> 1289             return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#    1290
#    1291     def _execute_function(self, func, multiparams, params, execution_options):
#
# ~\.conda\envs\py38\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     323     ):
#     324         if _force or self.supports_execution:
# --> 325             return connection._execute_clauseelement(
#     326                 self, multiparams, params, execution_options
#     327             )
#
# ~\.conda\envs\py38\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1479             linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1480         )
# -> 1481         ret = self._execute_context(
#    1482             dialect,
#    1483             dialect.execution_ctx_cls._init_compiled,
#
# ~\.conda\envs\py38\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1843
#    1844         except BaseException as e:
# -> 1845             self._handle_dbapi_exception(
#    1846                 e, statement, parameters, cursor, context
#    1847             )
#
# ~\.conda\envs\py38\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2024                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2025             elif should_wrap:
# -> 2026                 util.raise_(
#    2027                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2028                 )
#
# ~\.conda\envs\py38\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~\.conda\envs\py38\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1780                             break
#    1781                 if not evt_handled:
# -> 1782                     self.dialect.do_executemany(
#    1783                         cursor, statement, parameters, context
#    1784                     )
#
# ~\.conda\envs\py38\lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py in do_executemany(self, cursor, statement, parameters, context)
#     191
#     192     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 193         rowcount = cursor.executemany(statement, parameters)
#     194         if context is not None:
#     195             context._rowcount = rowcount
#
# ~\.conda\envs\py38\lib\site-packages\pymysql\cursors.py in executemany(self, query, args)
#     171             q_postfix = m.group(3) or ""
#     172             assert q_values[0] == "(" and q_values[-1] == ")"
# --> 173             return self._do_execute_many(
#     174                 q_prefix,
#     175                 q_values,
#
# ~\.conda\envs\py38\lib\site-packages\pymysql\cursors.py in _do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     209                 sql += b","
#     210             sql += v
# --> 211         rows += self.execute(sql + postfix)
#     212         self.rowcount = rows
#     213         return rows
#
# ~\.conda\envs\py38\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     146         query = self.mogrify(query, args)
#     147
# --> 148         result = self._query(query)
#     149         self._executed = query
#     150         return result
#
# ~\.conda\envs\py38\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     308         self._last_executed = q
#     309         self._clear_result()
# --> 310         conn.query(q)
#     311         self._do_get_result()
#     312         return self.rowcount
#
# ~\.conda\envs\py38\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     546             sql = sql.encode(self.encoding, "surrogateescape")
#     547         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 548         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     549         return self._affected_rows
#     550
#
# ~\.conda\envs\py38\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#     773         else:
#     774             result = MySQLResult(self)
# --> 775             result.read()
#     776         self._result = result
#     777         if result.server_status is not None:
#
# ~\.conda\envs\py38\lib\site-packages\pymysql\connections.py in read(self)
#    1154     def read(self):
#    1155         try:
# -> 1156             first_packet = self.connection._read_packet()
#    1157
#    1158             if first_packet.is_ok_packet():
#
# ~\.conda\envs\py38\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     723             if self._result is not None and self._result.unbuffered_active is True:
#     724                 self._result.unbuffered_active = False
# --> 725             packet.raise_for_error()
#     726         return packet
#     727
#
# ~\.conda\envs\py38\lib\site-packages\pymysql\protocol.py in raise_for_error(self)
#     219         if DEBUG:
#     220             print("errno =", errno)
# --> 221         err.raise_mysql_exception(self._data)
#     222
#     223     def dump(self):
#
# ~\.conda\envs\py38\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     141     if errorclass is None:
#     142         errorclass = InternalError if errno < 1000 else OperationalError
# --> 143     raise errorclass(errno, errval)
#
# OperationalError: (pymysql.err.OperationalError) (1054, "Unknown column 'PM2.5' in 'field list'")
# [SQL: INSERT INTO `AQI_hour` (`DataCreationDate`, `County`, `SiteName`, `AQI`, `SO2`, `CO`, `O3`, `PM10`, `PM2.5`, `NO2`, `NOx`, `NO`, `WindSpeed`, `WindDirec`) VALUES (%(DataCreationDate)s, %(County)s, %(SiteName)s, %(AQI)s, %(SO2)s, %(CO)s, %(O3)s, %(PM10)s, %(PM2.5)s, %(NO2)s, %(NOx)s, %(NO)s, %(WindSpeed)s, %(WindDirec)s)]
# [parameters: ({'DataCreationDate': '2018-01-31 23:00', 'County': '桃園市', 'SiteName': '平鎮', 'AQI': 38.0, 'SO2': 1.8, 'CO': 0.4, 'O3': 36.0, 'PM10': 29.0, 'PM2.5': '18', 'NO2': 0.5, 'NOx': 8.6, 'NO': 8.1, 'WindSpeed': 3.7, 'WindDirec': 34.0}, {'DataCreationDate': '2018-01-31 23:00', 'County': '桃園市', 'SiteName': '中壢', 'AQI': 25.0, 'SO2': 2.2, 'CO': 0.6, 'O3': 31.0, 'PM10': 21.0, 'PM2.5': '2', 'NO2': 16.0, 'NOx': 21.0, 'NO': 5.2, 'WindSpeed': 2.4, 'WindDirec': 31.0}, {'DataCreationDate': '2018-01-31 23:00', 'County': '桃園市', 'SiteName': '桃園', 'AQI': 31.0, 'SO2': 2.4, 'CO': 0.33, 'O3': 41.0, 'PM10': 19.0, 'PM2.5': '7', 'NO2': 5.2, 'NOx': 6.3, 'NO': 1.1, 'WindSpeed': 2.2, 'WindDirec': 17.0}, {'DataCreationDate': '2018-01-31 23:00', 'County': '桃園市', 'SiteName': '龍潭', 'AQI': 30.0, 'SO2': 2.0, 'CO': 0.38, 'O3': 39.0, 'PM10': 17.0, 'PM2.5': '4', 'NO2': 7.9, 'NOx': 9.1, 'NO': 1.2, 'WindSpeed': 4.7, 'WindDirec': 57.0}, {'DataCreationDate': '2018-01-31 23:00', 'County': '桃園市', 'SiteName': '大園', 'AQI': 39.0, 'SO2': 0.8, 'CO': 0.41, 'O3': 46.0, 'PM10': 23.0, 'PM2.5': 'ND', 'NO2': 1.1, 'NOx': 6.0, 'NO': 4.8, 'WindSpeed': 12.0, 'WindDirec': 22.0}, {'DataCreationDate': '2018-01-31 23:00', 'County': '桃園市', 'SiteName': '觀音', 'AQI': 35.0, 'SO2': 0.8, 'CO': 0.44, 'O3': 39.0, 'PM10': 25.0, 'PM2.5': '8', 'NO2': None, 'NOx': None, 'NO': None, 'WindSpeed': 8.4, 'WindDirec': 11.0}, {'DataCreationDate': '2018-01-31 22:00', 'County': '桃園市', 'SiteName': '中壢', 'AQI': 28.0, 'SO2': 2.1, 'CO': 0.67, 'O3': 24.0, 'PM10': 23.0, 'PM2.5': '4', 'NO2': 22.0, 'NOx': 33.0, 'NO': 10.0, 'WindSpeed': 2.3, 'WindDirec': 21.0}, {'DataCreationDate': '2018-01-31 22:00', 'County': '桃園市', 'SiteName': '平鎮', 'AQI': 33.0, 'SO2': 1.8, 'CO': 0.45, 'O3': 33.0, 'PM10': 33.0, 'PM2.5': '18', 'NO2': 0.4, 'NOx': 10.0, 'NO': 10.0, 'WindSpeed': 4.3, 'WindDirec': 34.0}  ... displaying 10 of 4427 total bound parameter sets ...  {'DataCreationDate': '2018-01-01 00:00', 'County': '桃園市', 'SiteName': '中壢', 'AQI': 113.0, 'SO2': 1.4, 'CO': 0.55, 'O3': 32.0, 'PM10': 83.0, 'PM2.5': '16.0', 'NO2': 14.0, 'NOx': 19.0, 'NO': 5.3, 'WindSpeed': 1.5, 'WindDirec': 0.2}, {'DataCreationDate': '2018-01-01 00:00', 'County': '桃園市', 'SiteName': '大園', 'AQI': 91.0, 'SO2': 1.6, 'CO': 0.32, 'O3': 41.0, 'PM10': 89.0, 'PM2.5': '14.0', 'NO2': 12.0, 'NOx': 13.0, 'NO': 1.1, 'WindSpeed': 5.1, 'WindDirec': 55.0})]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %%
date="2021/04"
date[0:4]+"_"+date[5:7]
# Out:
# '2021_04'

# %%
input_list=[]
start_year=2021
start_month=12
end_year=2018
end_month=1
for yearlist in range(end_year,start_year+1,1):
#     print (yearlist)
    if end_year != yearlist:
        for month in range(1,13):
            input_list.append(str(yearlist) + "/" + str(month).zfill(2))
    else:
        for month in range(end_month,13):
            input_list.append(str(yearlist) + "/" + str(month).zfill(2))
input_list[0]
# Out:
# '2018/01'

# %%
resource_id=dict_resource_id.get(get_list_date)
# Out:
# 時間 2021/12
# resource_id 6a75cd30-a36d-4695-81a8-23cfb17e63a8
# 時間 2021/11
# resource_id 70d312ec-c971-42c5-92da-7a6017e3a915
# 時間 2021/10
# resource_id befffe9b-94c7-444d-8a3b-37dc80405440
# 時間 2021/09
# resource_id 979f08ab-217c-4c40-87b7-3a20727d8f06
# 時間 2021/08
# resource_id 9e878209-8d8f-4bc0-8f68-4a0d55539d3f
# 時間 2021/07
# resource_id 73bb04f1-1b6e-4ec1-8276-ee997626fb8a
# 時間 2021/06
# resource_id edc46c97-a76d-4adf-939b-03a5bb1c4046
# 時間 2021/05
# resource_id 99b1fd62-ada4-4a05-a2fe-db2666077ad5
# 時間 2021/04
# resource_id 15b7c86a-f9a5-48d5-bcd9-b63387859e86
# 時間 2021/03
# resource_id 91653ca8-51b3-4edc-928e-8e0ad3a3bbd2
# 時間 2021/02
# resource_id fcdb5735-9e00-4c00-82cc-13260eec5091
# 時間 2021/01
# resource_id 179c7a7f-b79c-4d6c-9be7-c2cdbb8256a9
# 時間 2020/12
# resource_id 0a19384d-1654-4161-ba74-d47d10cb6044
# 時間 2020/11
# resource_id e241419c-a5bb-463f-96b5-ca08ceb5c3ed
# 時間 2020/10
# resource_id 819b4731-2959-4d17-bff3-059d3cf6eb9a
# 時間 2020/09
# resource_id bacce312-9d63-4d67-864e-b62de60a3587
# 時間 2020/08
# resource_id 7e38122d-1569-45df-9145-5a6e0dc22253
# 時間 2020/07
# resource_id aabd3246-53ab-4214-b796-a895eeaa16d9
# 時間 2020/06
# resource_id 7206e722-9274-49d3-87e9-2428ceae1f01
# 時間 2020/05
# resource_id d2993f27-6037-497b-8185-4a56655e8c52
# 時間 2020/04
# resource_id 808696de-43ae-40a5-9f49-cfb320f9b290
# 時間 2020/03
# resource_id 16371210-fe36-4638-b0aa-0f0fb47adc1a
# 時間 2020/02
# resource_id 0c6a991d-7ae5-4bd0-8268-ea914c264437
# 時間 2020/01
# resource_id 31c91fdd-7335-4b1d-bae8-b08f69284af3
# 時間 2019/12
# resource_id 098aaf3b-c44b-4e39-8323-0238056d3ad0
# 時間 2019/11
# resource_id 9c61f023-f398-4ce3-a9bc-5e754309c69d
# 時間 2019/10
# resource_id dfea57c1-b0c3-47d9-ba07-4ea1a5e3be14
# 時間 2019/09
# resource_id 837ff081-3db9-4b27-98dc-13fef2f0e0e9
# 時間 2019/08
# resource_id e8fdb331-4a5d-49fb-834c-6b855765b5ae
# 時間 2019/07
# resource_id 7b28386e-6624-4b26-a007-a977cbb14ddf
# 時間 2019/06
# resource_id 2291da3f-2bf0-4a6e-91ea-9563bd24a7ad
# 時間 2019/05
# resource_id 62e6b78a-3e01-4d70-b0e4-b368c40558e1
# 時間 2019/04
# resource_id 49366a14-e7a0-4ba4-85b3-09feab3b39ba
# 時間 2019/03
# resource_id 1e8375a5-0d9d-4c25-aa9a-ca0a8b12dc40
# 時間 2019/02
# resource_id a06b10bc-b64b-4437-b692-8f26df65ef1e
# 時間 2019/01
# resource_id 3b445cf4-c2f6-48b3-9895-92d719018bc6
# 時間 2018/12
# resource_id 3753407f-09dd-47fa-9b42-cefaa365ec0b
# 時間 2018/11
# resource_id 99afe70a-e5cb-420b-996d-3e2bd77555ed
# 時間 2018/10
# resource_id cfd0113d-31ff-46da-977f-d7171fe0796e
# 時間 2018/09
# resource_id f2ee9685-74d7-427c-810e-92b33c66cd78
# 時間 2018/08
# resource_id d78998a8-2972-42d5-9f41-3af5e56993e2
# 時間 2018/07
# resource_id 5a6ff815-1faf-4fc3-92be-e55fe3a203e7
# 時間 2018/06
# resource_id 27434c04-451c-493b-a6cb-14542a6d1efc
# 時間 2018/05
# resource_id c5447c2e-6216-4280-8c81-29f559aad813
# 時間 2018/04
# resource_id d324362a-aaf0-463c-9ce3-4a99ad603bfe
# 時間 2018/03
# resource_id 4ef74e1a-537f-4c9e-af78-51ef0f362e0b
# 時間 2018/02
# resource_id 6edd2001-d1de-4ff8-a910-472d09a1cd34
# 時間 2018/01
# resource_id 2f9a55db-ba65-4734-878f-992c6d603977
# 時間 2017/12
# resource_id 97415e60-9d4a-41da-944f-2b592a69f354
# 時間 2017/11
# resource_id ff20bfb3-fc44-47cb-9146-2ae1aa1ceddd
# 時間 2017/10
# resource_id b7861b43-e60a-44b9-ab60-34214bd19dff
# 時間 2017/09
# resource_id 8ef55af1-0cab-43b1-aeca-5dff4491e52d
# 時間 2017/08
# resource_id e80b9dd2-6e12-4a57-a5fe-afd1d9d6b004
# 時間 2017/07
# resource_id e1413c60-309d-4ae4-bf0a-751c27e7a63f
# 時間 2017/06
# resource_id 6a9fadd2-0f21-4d6d-b040-a176059c6370
# 時間 2017/05
# resource_id d7a698c1-f5e5-4b49-a6ff-5c0b6ca42d5b
# 時間 2017/04
# resource_id 8f681312-6660-4977-997f-0a6b75c29394
# 時間 2017/03
# resource_id d18f3f0d-c226-4076-a257-d8e54ecc586a
# 時間 2017/02
# resource_id bbbd1230-479c-42f3-a354-0f2dce41dad8
# 時間 2017/01
# resource_id d300b799-d3af-43c9-a0bd-3fced739bd1f
# 時間 2016/12
# resource_id 7ffd544c-8cdc-462f-b09d-25ae60ec3b71
# 時間 2016/11
# resource_id 90cdcdb4-0fb0-44f8-87eb-bae047a06cdb

# %%
def get_totol(resource_id):
    limit=10
    url_get_totol = 'https://data.epa.gov.tw/api/3/action/datastore_search?api_key=9be7b239-557b-4c10-9775-78cadfc555e9&resource_id=' + resource_id + '&q={%22County%22:%22%E6%A1%83%E5%9C%92%E5%B8%82%22}&limit=' + str(limit)
    resp = requests.get(url)
    soup = BeautifulSoup(resp.text, features="html.parser")
    data = json.loads(resp.text)
#     totol=data['result']['total']
    return str(totol)
resource_id='819b4731-2959-4d17-bff3-059d3cf6eb9a'
get_totol(resource_id)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23340/1120177200.py in <module>
#       8     return str(totol)
#       9 resource_id='819b4731-2959-4d17-bff3-059d3cf6eb9a'
# ---> 10 get_totol(resource_id)
#
# ~\AppData\Local\Temp/ipykernel_23340/1120177200.py in get_totol(resource_id)
#       4     resp = requests.get(url)
#       5     soup = BeautifulSoup(resp.text, features="html.parser")
# ----> 6     data = json.loads(resp.text)
#       7 #     totol=data['result']['total']
#       8     return str(totol)
#
# ~\.conda\envs\py38\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# ~\.conda\envs\py38\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~\.conda\envs\py38\lib\json\decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 2 column 1 (char 1)

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <!--[if IE 9]> <html lang="zh_TW" class="ie9"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html lang="zh-Hant">
# <!--<![endif]-->
# <head>
# <link href="/fanstatic/vendor/:version:2021-12-01T02:13:00.21/select2/select2.css" rel="stylesheet" type="text/css"/>
# <link href="/fanstatic/css/:version:2021-12-01T02:12:59.42/main.min.css" rel="stylesheet" type="text/css"/>
# <link href="/fanstatic/vendor/:version:2021-12-01T02:13:00.21/font-awesome/css/font-awesome.min.css" rel="stylesheet" type="text/css"/>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-160646801-1"></script>
# <script>
#               window.dataLayer = window.dataLayer || [];
#               function gtag(){dataLayer.push(arguments);}
#               gtag('js', new Date());
#
#               gtag('config', 'UA-160646801-1');
#             </script>
# <!-- 123 -->
# <meta charset="utf-8"/>
# <meta content="ckan 2.8.3" name="generator"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title>空氣品質指標(AQI)(歷史資料) - 資料集 - 行政院環保署 EPA</title>
# <link href="/base/images/epa.ico" rel="shortcut icon"/>
# <link href="https://fonts.googleapis.com/css?family=Noto+Sans+TC:400,500&amp;display=swap&amp;subset=chinese-traditional" rel="stylesheet"/>
# <link href="/base/css/custom.css" rel="stylesheet">
# <meta content="空氣品質指標(AQI)(歷史資料) - 行政院環保署 EPA" property="og:title"/>
# <meta content="每小時提供各測站之空氣品質指標（AQI）" property="og:description"/>
# </link></head>
# <body data-locale-root="https://data.epa.gov.tw/" data-site-root="https://data.epa.gov.tw/">
# <div class="hide"><a href="#content">跳至內容</a></div>
# <header class="masthead blue-bg2">
# <div class="">
# <div class="row vertical-align">
# <a class="jump-to-content" href="#content" tabindex="1" title="跳至主要內容">跳至主要內容</a>
# <hgroup class="header-image col-md-3">
# <h1>
# <a class="logo" href="/"><img alt="行政院環保署 EPA" src="/base/images/epa-logo.png" title="行政院環保署 EPA"/></a>
# <style>
#   .full-width {
#     width: 300px;
#     max-width: 100%;
#   }
# </style>
# </h1>
# </hgroup>
# <div class="nav-toggle"><span></span></div>
# <div class="account-toggle"><span></span></div>
# <div class="col-md-6 main-nav" id="main-navigation-toggle">
# <nav class="section">
# <a accesskey="U" class="guide_brick" href="javascript:;" title="頁首區塊">:::</a>
# <ul class="nav nav-pills">
# <li class="dropdown">
# <a aria-expanded="false" aria-haspopup="true" class="dropdown-toggle" data-toggle="dropdown" href="javascript:;" role="button">
#                 資料目錄<i aria-hidden="true" class="fa fa-caret-down"></i>
# </a>
# <ul class="dropdown-menu">
# <li>
# <a href="/dataset" title="資料集目錄">資料集目錄</a>
# </li>
# <li class="divider" role="separator"></li>
# <li><a download="DataList.csv" href="https://opendata2.epa.gov.tw/DataList.csv">資料集清單下載csv</a></li>
# </ul>
# </li>
# <li>
# <a href="/announcement" title="Announcement">系統公告</a>
# </li>
# <li class="dropdown">
# <a aria-expanded="false" aria-haspopup="true" class="dropdown-toggle" data-toggle="dropdown" href="javascript:;" role="button">
#                 關於平臺<i aria-hidden="true" class="fa fa-caret-down"></i>
# </a>
# <ul class="dropdown-menu">
# <li>
# <a href="/platform_origin" title="平臺緣起">平臺緣起</a>
# </li>
# <li class="divider" role="separator"></li>
# <li><a href="/qa">常見問答</a></li>
# <li class="divider" role="separator"></li>
# <li>
# <a href="/organization">協力單位</a>
# </li>
# <li class="divider" role="separator"></li>
# <!-- <li><a href="/sitemap">網站導覽</a></li> -->
# <li class="divider" role="separator"></li>
# <li><a href="https://docs.google.com/forms/d/1HzoYkIBt58GPMcaSYlwDHNaEs6F3-foobzAQMHsCwb0/edit" target="_blank" title="另開新視窗">
#                   問卷調查
#                   <i class="fa fa-external-link-square" title="另開新視窗"></i>
# </a></li>
# <li class="divider" role="separator"></li>
# <li>
# <a href="https://epamail.epa.gov.tw/front/mailboxhome" target="_blank" title="另開新視窗">
#                     意見信箱<i class="fa fa-external-link-square" title="另開新視窗"></i>
# </a>
# </li>
# </ul>
# </li>
# <li class="dropdown">
# <a aria-expanded="false" aria-haspopup="true" class="dropdown-toggle" data-toggle="dropdown" href="javascript:;" role="button">
#                 開發指南<i aria-hidden="true" class="fa fa-caret-down"></i>
# </a>
# <ul class="dropdown-menu">
# <li>
# <a href="/paradigm">API 使用說明</a>
# </li>
# <li class="divider" role="separator"></li>
# <li>
# <a href="/api_term" title="API介接服務條款">API介接服務條款</a>
# </li>
# <li class="divider" role="separator"></li>
# <li>
# <a href="/data_specification" title="資料規範">資料規範</a>
# </li>
# <li class="divider" role="separator"></li>
# <li>
# <a href="/privacy_statement" title="隱私權保護宣告">隱私權保護宣告</a>
# </li>
# <li class="divider" role="separator"></li>
# <li><a href="/api/v1/" title="資料擷取API線上說明文件">資料擷取API線上說明文件</a></li>
# </ul>
# </li>
# <li>
# <a href="/sitemap">網站導覽</a>
# </li>
# </ul>
# </nav>
# </div>
# <div class="col-md-3 account-nav">
# <nav class="account not-authed">
# <ul class="nav nav-pills">
# <li><a href="/api_term">會員註冊</a></li>
# <li class="blue-bg"><a href="/user/login">登入</a></li>
# <li>
# <a class="header-lang" href="/en/dataset/aqx_p_488">EN</a>
# </li>
# </ul>
# </nav>
# </div>
# </div>
# </div>
# </header>
# <noscript class="white">Your browser does not support JavaScript! 您的瀏覽器不支援JavaScript功能，若網頁功能無法正常使用時，請開啟瀏覽器JavaScript狀態。</noscript>
# <style>
#   .white {
#     color: #fff;
#   }
# </style>
# <div role="main">
# <div class="container" id="content">
# <div class="flash-messages">
# </div>
# <div class="toolbar">
# <a accesskey="C" class="guide_brick" href="javascript:;" title="主要內容區塊">:::</a>
# <ol class="breadcrumb">
# <li class="home"><a href="/" title="首頁"><i aria-hidden="true" class="fa fa-home"></i><span> 首頁</span></a></li>
# <li><a href="/organization">協力單位</a></li>
# <li><a href="/organization/000001-355000000i">環境監測及資訊處</a></li>
# <li class="active"><a class="active" href="/dataset/aqx_p_488">空氣品質指標(AQI)(歷史資料)</a></li>
# </ol>
# </div>
# <div class="row">
# <aside class="secondary col-sm-3">
# <div class="module module-narrow module-shallow context-info">
# <section class="module-content">
# <div class="h2"><i aria-hidden="true" class="fa fa-building-o"></i> 協力單位</div>
# <div class="image">
# <a href="/organization/000001-355000000i">
# <img alt="環境監測及資訊處縮圖" src="/base/images/placeholder-organization.png" width="200"/>
# </a>
# </div>
# <span class="heading h2">環境監測及資訊處
#         </span>
# <p>
#             業務職掌
#
# 環境監測規劃管理與品質保證
# 空氣品質監測規劃與網站管理
# 環境資訊規劃設計
# 環境資訊操作維護
#
# 服務項目摘要
#
# 水質監測、空氣監測、網路行政、環境資訊
#  <a href="/organization/about/000001-355000000i">讀取更多</a>
# </p>
# <div class="nums">
# <dl class="label">
# <i aria-hidden="true" class="fa fa-group"></i>
# </dl>
# <dl>
# <dt>追蹤者</dt>
# <dd data-module="followers-counter" data-module-id="0f0d297b-f5b6-4ecc-80b7-5c4d23b34920" data-module-num_followers="67"><span>67</span></dd>
# </dl>
# <dl class="label">
# <i aria-hidden="true" class="fa fa-sitemap"></i>
# </dl>
# <dl>
# <dt>資料集</dt>
# <dd><span>217</span></dd>
# </dl>
# </div>
# <div class="follow_button">
# </div>
# </section>
# </div>
# </aside>
# <div class="primary col-sm-9 col-xs-12">
# <article class="module">
# <div class="module-content pkg-header">
# <section>
# <div class="row">
# <div class="col-md-7">
# <h2 class="fz-B">
#            空氣品質指標(AQI)(歷史資料)
#         </h2>
# <span class="insert-comment-thread"></span>
# </div>
# <div class="col-md-5">
# <table class="table table-borderless">
# <tbody>
# <tr>
# <td class="text-left"><i class="fa fa-group"></i> 追蹤人數</td>
# <td class="text-right col-md-4" data-module="followers-counter" data-module-id="81c4ba29-2152-4bdb-8153-3db85560587b" data-module-num_followers="18"><span>18</span>人</td>
# </tr>
# </tbody>
# </table>
# <div class="pull-right">
# <div class="follow_button">
# </div>
# </div>
# </div>
# </div>
# </section>
# </div>
# <div class="module-content pkg-nav">
# <ul class="nav nav-tabs">
# <li class="active"><a href="/dataset/aqx_p_488"><i class="fa fa-sitemap"></i> 資料集</a></li>
# </ul>
# </div>
# <div class="module-content">
# <div class="pkg-info">
# <section class="resources" id="dataset-resources">
# <div class="resource-list text-center">
# <table class="table vertical">
# <thead>
# <tr class="dataset-header resource">
# <th class="col-md-11">資料集名稱</th>
# <th class="col-md-1 text-center">下載</th>
# </tr>
# </thead>
# <tbody>
# <tr class="" data-id="6a75cd30-a36d-4695-81a8-23cfb17e63a8" data-title="空氣品質指標(AQI)(歷史資料)">
# <td class="text-left pl25" data-field="資料集名稱">
# <a href="/dataset/aqx_p_488/resource/6a75cd30-a36d-4695-81a8-23cfb17e63a8">
# <span class="heading">
#         空氣品質指標(AQI)(歷史資料)
#       </span>
# </a>
# </td>
# <td data-field="下載">
# <a download="" href="https://opendata2.epa.gov.tw/data/aqx_p_488/aqx_p_488_2021-12.zip" title="下載 空氣品質指標(AQI)(歷史資料) zip">
# <span class="sr-only">下載</span>
# <i aria-hidden="true" class="fa fa-cloud-download"></i>
# </a>
# </td>
# </tr>
# <tr class="" data-id="70d312ec-c971-42c5-92da-7a6017e3a915" data-title="空氣品質指標(AQI)(歷史資料) (2021/11)">
# <td class="text-left pl25" data-field="資料集名稱">
# <a href="/dataset/aqx_p_488/resource/70d312ec-c971-42c5-92da-7a6017e3a915">
# <span class="heading">
#         空氣品質指標(AQI)(歷史資料) (2021/11)
#       </span>
# </a>
# </td>
# <td data-field="下載">
# <a download="" href="https://opendata2.epa.gov.tw/data/aqx_p_488/aqx_p_488_2021-11.zip" title="下載 空氣品質指標(AQI)(歷史資料) (2021/11) zip">
# <span class="sr-only">下載</span>
# <i aria-hidden="true" class="fa fa-cloud-download"></i>
# </a>
# </td>
# </tr>
# <tr class="" data-id="befffe9b-94c7-444d-8a3b-37dc80405440" data-title="空氣品質指標(AQI)(歷史資料) (2021/10)">
# <td class="text-left pl25" data-field="資料集名稱">
# <a href="/dataset/aqx_p_488/resource/befffe9b-94c7-444d-8a3b-37dc80405440">
# <span class="heading">
#         空氣品質指標(AQI)(歷史資料) (2021/10)
#       </span>
# </a>
# </td>
# <td data-field="下載">
# <a download="" href="https://opendata2.epa.gov.tw/data/aqx_p_488/aqx_p_488_2021-10.zip" title="下載 空氣品質指標(AQI)(歷史資料) (2021/10) zip">
# <span class="sr-only">下載</span>
# <i aria-hidden="true" class="fa fa-cloud-download"></i>
# </a>
# </td>
# </tr>
# <tr class="" data-id="979f08ab-217c-4c40-87b7-3a20727d8f06" data-title="空氣品質指標(AQI)(歷史資料) (2021/09)">
# <td class="text-left pl25" data-field="資料集名稱">
# <a href="/dataset/aqx_p_488/resource/979f08ab-217c-4c40-87b7-3a20727d8f06">
# <span class="heading">
#         空氣品質指標(AQI)(歷史資料) (2021/09)
#       </span>
# </a>
# </td>
# <td data-field="下載">
# <a download="" href="https://opendata2.epa.gov.tw/data/aqx_p_488/aqx_p_488_2021-09.zip" title="下載 空氣品質指標(AQI)(歷史資料) (2021/09) zip">
# <span class="sr-only">下載</span>
# <i aria-hidden="true" class="fa fa-cloud-download"></i>
# </a>
# </td>
# </tr>
# <tr class="" data-id="9e878209-8d8f-4bc0-8f68-4a0d55539d3f" data-title="空氣品質指標(AQI)(歷史資料) (2021/08)">
# <td class="text-left pl25" data-field="資料集名稱">
# <a href="/dataset/aqx_p_488/resource/9e878209-8d8f-4bc0-8f68-4a0d55539d3f">
# <span class="heading">
#         空氣品質指標(AQI)(歷史資料) (2021/08)
#       </span>
# </a>
# </td>
# <td data-field="下載">
# <a download="" href="https://opendata2.epa.gov.tw/data/aqx_p_488/aqx_p_488_2021-08.zip" title="下載 空氣品質指標(AQI)(歷史資料) (2021/08) zip">
# <span class="sr-only">下載</span>
# <i aria-hidden="true" class="fa fa-cloud-download"></i>
# </a>
# </td>
# </tr>
# <tr class="" data-id="73bb04f1-1b6e-4ec1-8276-ee997626fb8a" data-title="空氣品質指標(AQI)(歷史資料) (2021/07)">
# <td class="text-left pl25" data-field="資料集名稱">
# <a href="/dataset/aqx_p_488/resource

# </td>
# </tr>
# </tbody>
# </table>
# </div>
# </section>
# </div>
# <section class="add-info" id="additional_info">
# <div class="row">
# <div class="col-xs-12">
# <h3 class="fz-C"><i class="fa fa-sitemap"></i>關於資料集</h3>
# <table class="table no-padding vertical info">
# <tbody>
# <tr>
# <td class="text-left col-lg-3">分類及編號</td>
# <td class="text-left col-lg-9">E00生活安全及品質</td>
# </tr>
# <tr>
# <td class="text-left col-lg-3">資料集名稱</td>
# <td class="text-left col-lg-9">空氣品質指標(AQI)(歷史資料)</td>
# </tr>
# <tr>
# <td class="text-left col-lg-3">資料集提供單位</td>
# <td class="text-left col-lg-9">環境監測及資訊處</td>
# </tr>
# <tr>
# <td class="text-left col-lg-3">資料集描述</td>
# <td class="text-left col-lg-9">每小時提供各測站之空氣品質指標（AQI）</td>
# </tr>
# <tr>
# <td class="text-left col-lg-3">主要資料欄位</td>
# <td class="text-left col-lg-9">SiteName(測站名稱)、County(縣市)、AQI(空氣品質指標)、Pollutant(空氣污染指標物)、Status(狀態)、SO2(二氧化硫(ppb))、CO(一氧化碳(ppm))、O3(臭氧(ppb))、O3_8hr(臭氧8小時移動平均(ppb))、PM10(懸浮微粒(μg/m3))、PM2.5(細懸浮微粒(μg/m3))、NO2(二氧化氮(ppb))、NOx(氮氧化物(ppb))、NO(一氧化氮(ppb))、WindSpeed(風速(m/sec))、WindDirec(風向(degrees))、DataCreationDate(資料發布時間)、Unit(單位)、CO_8hr(一氧化碳8小時移動平均(ppm))、PM2.5_AVG(細懸浮微粒移動平均值(μg/m3))、PM10_AVG(懸浮微粒移動平均值(μg/m3))、SO2_AVG(二氧化硫移動平均值(ppb))、Longitude(經度)、Latitude(緯度)、SiteId(測站編號)。</td>
# </tr>
# <tr>
# <td class="text-left col-lg-3">資料集類別</td>
# <td class="text-left col-lg-9">
# <span> 大氣 </span>
# </td>
# </tr>
# <tr>
# <td class="text-left col-lg-3">環境保護計畫類別</td>
# <td class="text-left col-lg-9">
#                             大氣環境
#                         </td>
# </tr>
# <tr>
# <td class="text-left col-lg-3">授權方式</td>
# <td class="text-left col-lg-9">依政府資料開放平臺使用規範</td>
# </tr>
# <tr>
# <td class="text-left col-lg-3">授權說明網址</td>
# <td class="text-left col-lg-9">
# <a href="https://data.gov.tw/license" target="_blank" title="另開新視窗 前往 授權說明網址">
#                                 https://data.gov.tw/license
#                                 <!-- <i class="fa fa-external-link-square" title="另開新視窗"></i> -->
# </a>
# </td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="col-xs-12">
# <h3 class="fz-C"><i class="fa fa-file"></i>資料格式</h3>
# <table class="table no-padding vertical info">
# <tbody>
# <tr>
# <td class="text-left col-lg-3">編碼格式</td>
# <td class="text-left col-lg-7">UTF-8</td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="col-xs-12">
# <h3 class="fz-C"><i class="fa fa-clock-o"></i>資料集時間</h3>
# <table class="table no-padding vertical info">
# <tbody>
# <tr>
# <td class="text-left col-lg-3">更新頻率</td>
# <td class="text-left col-lg-7">每小時更新</td>
# </tr>
# <tr>
# <td class="text-left col-lg-3">資料最後同步時間</td>
# <td class="text-left col-lg-7">
# <span class="automatic-local-datetime" data-datetime="2021/12/07">
#                 2021/12/07
#               </span>
# </td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="col-xs-12">
# <h3 class="fz-C"><i class="fa fa-phone"></i>聯絡資訊</h3>
# <table class="table no-padding vertical info">
# <tbody>
# <tr>
# <td class="text-left col-lg-3">聯絡人姓名</td>
# <td class="text-left col-lg-7">
#
#                                 謝小姐
#
#                         </td>
# </tr>
# <tr>
# <td class="text-left col-lg-3">聯絡人電話</td>
# <td class="text-left col-lg-7">02-23117722轉2335</td>
# </tr>
# <tr>
# <td class="text-left col-lg-3">聯絡人電子郵件</td>
# <td class="text-left col-lg-7">weiwen.hsieh@epa.gov.tw</td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="col-xs-12">
# <h3 class="fz-C"><i class="fa fa-tags"></i>標籤</h3>
# <div class="tag-wrap">
# </div>
# </div>
# </div>
# </section>
# </div>
# </article>
# </div>
# </div>
# </div>
# </div>
# <footer class="site-footer">
# <div class="container">
# <div class="row">
# <div class="col-xs-12 col-md-4">
# <a accesskey="Z" class="guide_brick" href="javascript:;" title="頁尾區塊">:::</a>
# <a class="logo" href="/"><img alt="行政院環保署 EPA" src="/base/images/epa-logo.png" title="行政院環保署 EPA"/></a>
# <style>
#   .full-width {
#     width: 300px;
#     max-width: 100%;
#   }
# </style>
# </div>
# <div class="col-xs-12 col-md-4">
# <ul>
# <li>
# <span>聯絡地址</span>
# <span><a href="#">10042臺北市中正區中華路一段83號</a></span>
# </li>
# <li>
# <span>客服電話</span>
# <span><a href="tel:02-25112393">(02)2511-2393</a></span>
# </li>
# <li>
# <span>客服信箱</span>
# <span><a href="mailto:a0-od@epa.gov.tw">a0-od@epa.gov.tw</a></span>
# </li>
# </ul>
# </div>
# <div class="col-xs-12 col-md-2">
# <ul class="link">
# <li>
# <span>更多連結</span>
# <span><a href="https://www.epa.gov.tw/Page/80191639AC8FA886" target="_blank" title="另開新視窗">
#                             資料安全政策
#                             <!-- <i class="fa fa-external-link-square" title="另開新視窗"></i> -->
# </a></span>
# <span><a href="/privacy_statement" target="_blank" title="另開新視窗">
#                             隱私權保護宣告
#                             <!-- <i class="fa fa-external-link-square" title="另開新視窗"></i> -->
# </a></span>
# <span><a href="/data_specification">資料規範</a></span>
# </li>
# </ul>
# </div>
# <div class="col-xs-12 col-md-2">
# <ul class="link">
# <li>
# <span>資料更新日期</span>
# <span>
#                             2021/12/08
#                         </span>
# </li>
# <li>
# <span>瀏覽人次</span>
# <span>
#                             1,579,896
#                         </span>
# </li>
# <li>
# <a href="https://accessibility.ncc.gov.tw/Applications/Detail?category=20210125115022" title="無障礙網站">
# <img alt="通過AA無障礙網頁檢測" border="0" height="31" src="/base/images/AA.6c477cb.svg" width="88"/>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </footer>
# <script>
#     var ms_ie = false;
#     var ua = window.navigator.userAgent;
#     var old_ie = ua.indexOf('MSIE ');
#     var new_ie = ua.indexOf('Trident/');
#     if ((old_ie > -1) && (new_ie > -1)) {
#         ms_ie = true;
#         document.documentElement.className += " oldie";
#
#     } else if ((old_ie === -1) && (new_ie > -1)) {
#         document.documentElement.className += " ie11";
#
#     }
# </script>
# <div id="sorryforie">
# <div>
# <p class="fz-B">
#             Sorry, this page does not support browsers below IE 10 <br/> Please use another browser.
#         </p>
# <div class="browser">
# <a href="https://www.microsoft.com/zh-tw/windows/microsoft-edge" title="Microsoft edge">
# <img alt="edge icon" src="/base/images/edge.svg"/>
# <span>Edge</span>
# </a>
# <a href="https://www.google.com/intl/zh-TW/chrome/" title="Google Chrome">
# <img alt="chrome icon" src="/base/images/chrome.svg"/>
# <span>Chrome</span>
# </a>
# <a href="https://www.mozilla.org/zh-TW/firefox/new/" title="Mozilla Firefox">
# <img alt="Firefox icon" src="/base/images/mozilla.svg"/>
# <span>Firefox</span>
# </a>
# <a href="https://www.opera.com/zh-tw" title="Opera">
# <img alt="opera icon" src="/base/images/opera.svg"/>
# <span>Opera</span>
# </a>
# </div>
# </div>
# </div>
# <script src="/base/javascript/js.cookie.min.js"></script>
# <script src="https://unpkg.com/@popperjs/core@2"></script>
# <script src="https://unpkg.com/tippy.js@6"></script>
# <script>document.getElementsByTagName('html')[0].className += ' js';</script>
# <script src="/fanstatic/vendor/:version:2021-12-01T02:13:00.21/jquery.min.js" type="text/javascript"></script>
# <script src="/fanstatic/vendor/:version:2021-12-01T02:13:00.21/:bundle:bootstrap/js/bootstrap.min.js;jed.min.js;moment-with-locales.js;select2/select2.min.js" type="text/javascript"></script>
# <script src="/fanstatic/base/:version:2021-12-01T02:12:59.59/:bundle:plugins/jquery.inherit.min.js;plugins/jquery.proxy-all.min.js;plugins/jquery.url-helpers.min.js;plugins/jquery.date-helpers.min.js;plugins/jquery.slug.min.js;plugins/jquery.slug-preview.min.js;plugins/jquery.truncator.min.js;plugins/jquery.masonry.min.js;plugins/jquery.form-warning.min.js;plugins/jquery.images-loaded.min.js;sandbox.min.js;module.min.js;pubsub.min.js;client.min.js;notify.min.js;i18n.min.js;main.min.js;modules/select-switch.min.js;modules/slug-preview.min.js;modules/basic-form.min.js;modules/confirm-action.min.js;modules/api-info.min.js;modules/autocomplete.min.js;modules/custom-fields.min.js;modules/data-viewer.min.js;modules/table-selectable-rows.min.js;modules/resource-form.min.js;modules/resource-upload-field.min.js;modules/resource-reorder.min.js;modules/resource-view-reorder.min.js;modules/follow.min.js;modules/activity-stream.min.js;modules/dashboard.min.js;modules/resource-view-embed.min.js;view-filters.min.js;modules/resource-view-filters-form.min.js;modules/resource-view-filters.min.js;modules/table-toggle-more.min.js;modules/dataset-visibility.min.js;modules/media-grid.min.js;modules/image-upload.min.js;modules/followers-counter.min.js" type="text/javascript"></script>
# <script src="/fanstatic/epa_theme/:version:2021-12-01T02:13:05.44/custom.js" type="text/javascript"></script></body>
# </html>
