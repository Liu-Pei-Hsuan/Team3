# %%
import requests
import json
from bs4 import BeautifulSoup
import pandas as pd
import re
from time import sleep
from datetime import datetime

# %%
url = "https://ecshweb.pchome.com.tw/search/v3.3/all/results?q=%E9%8D%B5%E7%9B%A4&page=1&sort=sale/dc"
userAgent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/95.0.4638.54 Safari/537.36"
headers = {
    'cookie': 'ECC=GoogleBot',
    "User-Agent" : userAgent
}

res = requests.get(url, headers = headers)
data = json.loads(res.text)
data
#soup = BeautifulSoup(res.text, "html.parser")
# Out:
# {'QTime': 31,
#  'totalRows': 14029,
#  'totalPage': 100,
#  'range': {'min': '', 'max': ''},
#  'cateName': '',
#  'q': '鍵盤',
#  'subq': '',
#  'token': ['鍵盤', '鍵', '盤'],
#  'isMust': 1,
#  'prods': [{'Id': 'DCBF0H-A900BSFGU',
#    'cateId': 'DCBF0H',
#    'picS': '/items/DCBF0HA900BSFGU/000002_1631868862.jpg',
#    'picB': '/items/DCBF0HA900BSFGU/000001_1635473086.jpg',
#    'name': 'Razer Pro Type 無線鍵盤 白色',
#    'describe': 'Razer Pro Type 無線鍵盤 白色 - 機械橘軸\\r\\n● 雷蛇機械橘軸\r\n● 無線 藍牙雙模\r\n● 最多支援4台裝置\r\n※本商品為英刻鍵帽，不含中文注音倉頡標示，購買前請留意※\r\n--------------------------',
#    'price': 2990,
#    'originPrice': 2990,
#    'author': '',
#    'brand': '',
#    'publishDate': '',
#    'sellerId': '',
#    'isPChome': 1,
#    'isNC17': 0,
#    'couponActid': [],
#    'BU': 'ec'},
#   {'Id': 'DCAH83-A90090HSO',
#    'cateId': 'DSAR1O',
#    'picS': '/items/DCAH83A90090HSO/000002_1635393574.jpg',
#    'picB': '/items/DCAH83A90090HSO/000001_1635393573.jpg',
#    'name': '羅技 G512 RGB 機械遊戲鍵盤(青軸)',
# ...

# %%
new_data = data["prods"][0]["describe"].split("●")[1:]
new_split = "".join(new_data).split("\r\n")
if len(new_split) > len(new_data):
    new_data = new_split[0:len(new_data)]
new_data
# Out:
# [' 雷蛇機械橘軸', ' 無線 藍牙雙模', ' 最多支援4台裝置']

# %%
new_data = data["prods"][0]["describe"].split("●")[1:]
if data["prods"][0]["describe"].split("●") != 0:
    print("y")
# Out:
# y

# %%
web_data = data["prods"]

for product in web_data:
    if "●" in product["describe"]:
        new_describe = product["describe"].split("●")[1:]
        describe_split = "".join(new_describe).split("\r\n")
        if len(describe_split) > len(new_describe):
            new_describe = describe_split[0:len(new_describe)]
        print("產品名稱：", product["name"])
        print("產品價格：", product["price"])
        print("產品資訊:", new_describe)
        print()
    elif "-" in product["describe"]:
        new_describe = product["describe"].split("-")[1:]
        describe_split = "".join(new_describe).split("\r\n")
        if len(describe_split) > len(new_describe):
            new_describe = describe_split[0:len(new_describe)]
        print("產品名稱：", product["name"])
        print("產品價格：", product["price"])
        print("產品資訊:", new_describe)
        print()
    elif "★" in product["describe"]:
        new_describe = product["describe"].split("★")[1:]
        describe_split = "".join(new_describe).split("\r\n")
        if len(describe_split) > len(new_describe):
            new_describe = describe_split[0:len(new_describe)]
        print("產品名稱：", product["name"])
        print("產品價格：", product["price"])
        print("產品資訊:", new_describe)
        print()
# Out:
# 產品名稱： Razer Pro Type 無線鍵盤 白色
# 產品價格： 2990
# 產品資訊: [' 雷蛇機械橘軸', ' 無線 藍牙雙模', ' 最多支援4台裝置']
#
# 產品名稱： 羅技 G512 RGB 機械遊戲鍵盤(青軸)
# 產品價格： 1990
# 產品資訊: [' gx clicky 敲擊感軸 (青軸)', ' usb2.0 轉接埠 ', ' 1680萬色 lightsync rgb 可自訂燈效 ', ' 航空等級鋁合金上蓋', ' 羅技台灣地區販售鍵盤，皆為中文標示有注音倉頡版本']
#
# 產品名稱： 羅技 G813 RGB機械式短軸遊戲鍵盤-青軸
# 產品價格： 3990
# 產品資訊: [' 低平鍵帽、纖薄外型、鋁合金上蓋', ' usb 2.0 轉接埠', ' 約1680萬色 lightsync rgb', ' 多媒體控制快捷鍵設計']
#
# 產品名稱： Razer 黑寡婦蜘幻彩版鍵盤 V3--綠軸
# 產品價格： 2888
# 產品資訊: [' razer™ 機械式綠軸', ' 雙射出成型abs鍵帽', ' 內建記憶體外加雲端的混合式儲存設定', ' 全區無衝突防鬼鍵設計', ' 多元佈線選項']
#
# 產品名稱： Razer 黑寡婦蜘幻彩版鍵盤 V3--黃軸
# 產品價格： 2888
# 產品資訊: [' razer™ 機械式綠軸', ' 雙射出成型abs鍵帽', ' 內建記憶體外加雲端的混合式儲存設定', ' 全區無衝突防鬼鍵設計', ' 多元佈線選項']
#
# 產品名稱： ASUS E410MA-1191PN4120 玫瑰金(Celeron N4120/8G/256G/Windows 10 Home/FHD/14)
# 產品價格： 15900
# 產品資訊: ['1191PN4120 玫瑰金14吋輕薄文書筆電★內含作業系統 \\r\\n全新獨特的外觀設計', 'intel  四核心處理器 n4120']
#
# 產品名稱： 羅技 G813 + G304 機械式遊戲鍵鼠組
# 產品價格： 3990
# 產品資訊: [' 低平鍵帽、纖薄外型、鋁合金上蓋', ' usb 2.0 轉接埠', ' 約1680萬色 lightsync rgb', ' 多媒體控制快捷鍵設計']
#
# ...

# %% [markdown]
# ## 收集產品連結清單

# %%
query = '筆電'
# 每次加載分頁有20筆資料，可以依需求增加/減少
pages = 2

# get prods list
prodids = []
for page in list(range(1, pages)):
    url = 'https://ecshweb.pchome.com.tw/search/v3.3/all/results?q={}&page={}&sort=sale/dc'.format(query, page)
    resp = requests.get(url,headers=headers)
    for prodid in resp.json()['prods']:
        prodids.append(prodid['Id'])
        prodids = list(set(prodids))
        
print('There are {} products in list.'.format(len(prodids)))
# Out:
# There are 20 products in list.

# %% [markdown]
# ## 爬取產品資料
# >Pchome 將產品資料放在兩個不同 API，因此我們在爬蟲時需要送產品 ID 到這兩個 API 上才能取到完整的資料。這裡建議先把所有商品在一個 API上的資料都抓完後再去取第二個 API 的資料，因為兩個 API response 的資料結構不一樣，在分析時會很容易搞混

# %%
# ecapi
df1 = []
for i, Id in enumerate(prodids):
    columns, values = [], []
    #print('Dealing with {}: {}'.format(i, Id))
    sleep(0.7)
    ecapi = 'https://mall.pchome.com.tw/ecapi/ecshop/prodapi/v2/prod/{}&fields=Seq,Id,Stmt,Slogan,Name,Nick,Store,PreOrdDate,SpeOrdDate,Price,Discount,Pic,Weight,ISBN,Qty,Bonus,isBig,isSpec,isCombine,isDiy,isRecyclable,isCarrier,isMedical,isBigCart,isSnapUp,isDescAndIntroSync,isFoodContents,isHuge,isEnergySubsidy,isPrimeOnly,isWarranty,isLegalStore,isOnSale,isPriceTask,isBidding,isETicket&_callback=jsonp_prod&1587196620'.format(Id)
    resp = requests.get(ecapi, headers=headers)
    data = re.sub('try{jsonp_prod\(|\}\);\}catch\(e\)\{if\(window.console\)\{console.log\(e\)\;\}','',resp.text)
    data = json.loads(data)[Id+'-000']

    for key, value in data.items():
        columns.append(key)
        values.append(value)
    ndf = pd.DataFrame(data=values, index=columns).T
    df1.append(ndf)
df1 = pd.concat(df1, ignore_index=True)
df1
# Out:
#          Seq                    Id  \
# 0   27551201  DHAK5V-A900BSESB-000
# 1   25505580  DHAEDE-1900AWHR7-000
# 2   27283746  DHAS4J-A900BN2W4-000
# 3   25833594  DHAEGO-1900B0D0X-000
# 4   21323029  DCAD6E-A9009I91S-000
# 5   26483684  DHAS4N-A900B7V2B-000
# 6   27165835  DHAFM7-A900BKYGK-000
# 7   26200207  DHAFLA-A900B4LA4-000
# 8   27238081  DHAS4M-A900BM6FZ-000
# 9   27271718  DHAFL8-A900BMVCD-000
# 10  27282963  DHAS6K-A900BN2GD-000
# 11  27694550  DHAS4K-A900BV9YL-000
# 12  25421587  DCADN0-A900AVHO7-000
# 13  27173597  DHAFM6-A900BL324-000
# 14  27476634  DHAS4K-A900BR13I-000
# 15  23318341  DCAD6E-A900A6Q56-000
# 16  27749184  DHAK5T-A900BWHI2-000
# 17  27275691  DHAXAI-A900BMXJW-000
# 18  27256401  DHAFLE-A900BMLB0-000
# 19  27155507  DHAFM7-A900BKOY2-000
#
#                                                  Name  \
# 0   MSI Creator Z16 Hiroshi Fujiwara A11UE-225TW(i...
# 1   ACER 514-55TA-55K5 綠(i5-1135G7/8G/512G PCIe/W1...
# ...

# %%
# cdn
df2 = []
for i, Id in enumerate(prodids):
    columns, values = [], []
    #print('Dealing with {}: {}'.format(i, Id))
    sleep(0.7)
    cdn = 'https://ecapi.pchome.com.tw/cdn/ecshop/prodapi/v2/prod/{}/desc&fields=Id,Stmt,Equip,Remark,Liability,Kword,Slogan,Author,Transman,Pubunit,Pubdate,Approve&_callback=jsonp_desc'.format(Id+'-000')
    resp = requests.get(cdn, headers=headers)
    data = re.sub('try\{jsonp_desc\(|\}\);\}catch\(e\)\{if\(window.console\)\{console.log\(e\)\;\}','',resp.text)
    data = json.loads(data)
    data = data[Id]

    for key, value in data.items():
        columns.append(key)
        values.append(value)
    ndf = pd.DataFrame(data=values, index=columns).T
    df2.append(ndf)

df2 = pd.concat(df2, ignore_index=True)
df2
# Out:
#                   Id                                               Stmt  \
# 0   DHAK5V-A900BSESB  <a name="123"></a>\r\n型號:Creator Z16 Hiroshi F...
# 1   DHAEDE-1900AWHR7  <a name="規格說明"> ACER 514-55TA-55K5 綠 詳細規格表</a>...
# 2   DHAS4J-A900BN2W4  FA506IC-0032A4800H幻影灰  詳細規格表 \r\n-------------...
# 3   DHAEGO-1900B0D0X
# 4   DCAD6E-A9009I91S  產品規格 / Specifications\r\n型號 / Model：APD-57W\r\...
# 5   DHAS4N-A900B7V2B  GA401QM-0032E5900HS 日蝕灰 詳細規格表 \r\n------------...
# 6   DHAFM7-A900BKYGK  <a name="規格說明">ASUS X515EP-0151G1135G7 星空灰 詳細規...
# 7   DHAFLA-A900B4LA4  <a name="規格說明"> ASUS VivoBook S15 S513EP-0322S...
# 8   DHAS4M-A900BM6FZ  <a name="規格說明">ROG Strix G513QE-0031C5900HX 潮魂...
# 9   DHAFL8-A900BMVCD  <a name="規格說明">ASUS X415JA-0361G1035G1 星空灰 詳細規...
# 10  DHAS6K-A900BN2GD  GA401QEC-0022G5900HS Alan Walker聯名款 詳細規格表 \r\n...
# 11  DHAS4K-A900BV9YL  <a name="規格說明">ASUS ROG Strix SCAR 17 G733QM-0...
# 12  DCADN0-A900AVHO7  顏色：黑色\r\n產地：中國\r\n材質：塑膠、金屬\r\n商品尺寸：7.5*3.6*3.2...
# ...

# %% [markdown]
# ## 合併兩個資料表
# >這裡就是我說資料結構不一致的地方，第一個 API 取回來的 產品 ID 最後會包含’-000’的字串，而第二個 API 取回來的則是乾淨的產品 ID，要將兩個資料表透過產品 ID 合併在一起時要先將 ’-000’ 的字串拿掉

# %%
df1['Id'] = df1['Id'].apply(lambda x: re.sub('-000$','',x))
df = pd.merge(df1, df2, how='left',on='Id')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20 entries, 0 to 19
# Data columns (total 45 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Seq                 20 non-null     object
#  1   Id                  20 non-null     object
#  2   Name                20 non-null     object
#  3   Nick                20 non-null     object
#  4   Store               20 non-null     object
#  5   PreOrdDate          20 non-null     object
#  6   SpeOrdDate          20 non-null     object
#  7   Price               20 non-null     object
#  8   Discount            20 non-null     object
#  9   Pic                 20 non-null     object
#  10  Weight              20 non-null     object
#  11  ISBN                20 non-null     object
#  12  Qty                 20 non-null     object
#  13  Bonus               20 non-null     object
#  14  isBig               20 non-null     object
# ...
